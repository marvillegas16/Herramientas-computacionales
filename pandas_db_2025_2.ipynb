# %% [markdown]
# <a href="https://colab.research.google.com/github/marvillegas16/Herramientas-computacionales/blob/main/pandas_db_2025_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#from google.colab import files
#df=files.upload()
#print(df)

link='https://github.com/mike1502/HerramientasComputacionales/blob/main/Pandas/ebola_2014_2016_clean.csv'
code='?raw=true' #para que pandas lea el archivo csv y se pueda procesar
url=link+code # se unen el link y el código para leer el archivo
df=pd.read_csv(url,sep=',',index_col=1) #cargar archivo a la variable df

# %%
df.head(5) # Visualizar el encabezado del dataframe (base de datos). Por default, muestra las primeras 5 filas
# y el encabezado
# Out:
#                  Country  No. of confirmed cases  No. of confirmed deaths  \
# Date
# 29/08/2014        Guinea                     482                    287.0
# 29/08/2014       Nigeria                      15                      6.0
# 29/08/2014  Sierra Leone                     935                    380.0
# 29/08/2014       Liberia                     322                    225.0
# 05/09/2014        Guinea                     604                    362.0
#
#             Male Cases  Female Cases    Boys   Girls  Adult Male  \
# Date
# 29/08/2014       289.2         192.8   86.76   57.84      173.52
# 29/08/2014         9.0           6.0    2.70    1.80        5.40
# 29/08/2014       561.0         374.0  168.30  112.20      336.60
# 29/08/2014       193.2         128.8   57.96   38.64      115.92
# 05/09/2014       362.4         241.6  108.72   72.48      217.44
#
#             Adult Female  Old Male  Old Female
# Date
# 29/08/2014        115.68     28.92       19.28
# ...

# %%
df.tail(10) # Es para visualizar las últimas 5 filas del dataframe
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 23/03/2016              Sierra Leone                    8704
# 23/03/2016                   Senegal                       1
# 23/03/2016                      Mali                       7
# 23/03/2016            United Kingdom                       1
# 23/03/2016                   Liberia                       9
# 23/03/2016                   Liberia                    3151
# 23/03/2016                     Italy                       1
# 23/03/2016                   Liberia                       2
# 23/03/2016                   Nigeria                      19
# 23/03/2016  United States of America                       4
#
#             No. of confirmed deaths  Male Cases  Female Cases     Boys  \
# Date
# 23/03/2016                   3589.0      5222.4        3481.6  1566.72
# 23/03/2016                      0.0         0.6           0.4     0.18
# ...

# %%
df.info() # Visualizar la información general del dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2484 entries, 29/08/2014 to 23/03/2016
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  2484 non-null   object
#  1   No. of confirmed cases   2484 non-null   int64
#  2   No. of confirmed deaths  1648 non-null   float64
#  3   Male Cases               2484 non-null   float64
#  4   Female Cases             2484 non-null   float64
#  5   Boys                     2484 non-null   float64
#  6   Girls                    2484 non-null   float64
#  7   Adult Male               2484 non-null   float64
#  8   Adult Female             2484 non-null   float64
#  9   Old Male                 2484 non-null   float64
#  10  Old Female               2484 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 232.9+ KB

# %%
df.describe() # visualizar las estadísticas de cada columna
# Out:
#        No. of confirmed cases  No. of confirmed deaths   Male Cases  \
# count             2484.000000              1648.000000  2484.000000
# mean              1436.616345               781.662015   861.969807
# std               2574.200797              1258.113098  1544.520478
# min                  1.000000                 0.000000     0.600000
# 25%                  1.000000                 0.000000     0.600000
# 50%                  7.000000                 2.000000     4.200000
# 75%               3118.000000              1760.750000  1870.800000
# max               8704.000000              3858.000000  5222.400000
#
#        Female Cases         Boys        Girls   Adult Male  Adult Female  \
# count   2484.000000  2484.000000  2484.000000  2484.000000   2484.000000
# mean     574.646538   258.590942   172.393961   517.181884    344.787923
# std     1029.680319   463.356143   308.904096   926.712287    617.808191
# ...

# %%
df['Country'].isin(['Mexico']).sum()
# Consulto en el DF, en la columna de país, si existe información sobre el ébola en México
# Out:
# np.int64(0)

# %%
df.isnull().sum()
#Entro al df para buscar datos nulos y sumarlos
# Out:
# Country                      0
# No. of confirmed cases       0
# No. of confirmed deaths    836
# Male Cases                   0
# Female Cases                 0
# Boys                         0
# Girls                        0
# Adult Male                   0
# Adult Female                 0
# Old Male                     0
# Old Female                   0
# dtype: int64

# %%
promedio_muertos=df['No. of confirmed deaths'].mean()
df['No. of confirmed deaths'].fillna(promedio_muertos,inplace=True)
# Out:
# <ipython-input-8-0bde72012b72>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['No. of confirmed deaths'].fillna(promedio_muertos,inplace=True)

# %%
df.tail(10)
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 23/03/2016              Sierra Leone                    8704
# 23/03/2016                   Senegal                       1
# 23/03/2016                      Mali                       7
# 23/03/2016            United Kingdom                       1
# 23/03/2016                   Liberia                       9
# 23/03/2016                   Liberia                    3151
# 23/03/2016                     Italy                       1
# 23/03/2016                   Liberia                       2
# 23/03/2016                   Nigeria                      19
# 23/03/2016  United States of America                       4
#
#             No. of confirmed deaths  Male Cases  Female Cases     Boys  \
# Date
# 23/03/2016              3589.000000      5222.4        3481.6  1566.72
# 23/03/2016                 0.000000         0.6           0.4     0.18
# ...

# %%
df.isnull().sum() #repetimos el comando para verificar que ya no tenemos datos nulos
# Out:
# Country                    0
# No. of confirmed cases     0
# No. of confirmed deaths    0
# Male Cases                 0
# Female Cases               0
# Boys                       0
# Girls                      0
# Adult Male                 0
# Adult Female               0
# Old Male                   0
# Old Female                 0
# dtype: int64

# %%
#vamos a contar los casos por país
conteo=df.groupby('Country').size().reset_index(name='conteo')
conteo=conteo.sort_values('conteo',ascending=False)
conteo
# Out:
#                     Country  conteo
# 2                   Liberia     364
# 0                    Guinea     259
# 6              Sierra Leone     259
# 4                   Nigeria     255
# 5                   Senegal     254
# 9  United States of America     245
# 7                     Spain     243
# 3                      Mali     243
# 8            United Kingdom     221
# 1                     Italy     141

# %%
data_missing=df['No. of confirmed deaths'].isnull().groupby(df['Country']).sum()
data_missing=data_missing.sort_values(ascending=False)
print(data_missing)
# Out:
# Country
# Guinea                      0
# Italy                       0
# Liberia                     0
# Mali                        0
# Nigeria                     0
# Senegal                     0
# Sierra Leone                0
# Spain                       0
# United Kingdom              0
# United States of America    0
# Name: No. of confirmed deaths, dtype: int64

# %%
plt.pie(conteo['conteo'],labels=conteo['Country'],autopct='%1.1f%%')
plt.axis('equal')
plt.title('Casos de Ebola por país')
plt.savefig('CasosEbolaPorPais.png',dpi=300,format='png')
plt.show()

# %%
Guinea=df[df['Country']=='Guinea']
Guinea.head(5)

#espana=df[df['Country']=='Spain']
#espana.head(15)
# Out:
#            Country  No. of confirmed cases  No. of confirmed deaths  \
# Date
# 29/08/2014  Guinea                     482                    287.0
# 05/09/2014  Guinea                     604                    362.0
# 08/09/2014  Guinea                     664                    400.0
# 12/09/2014  Guinea                     678                    403.0
# 16/09/2014  Guinea                     743                    429.0
#
#             Male Cases  Female Cases    Boys  Girls  Adult Male  Adult Female  \
# Date
# 29/08/2014       289.2         192.8   86.76  57.84      173.52        115.68
# 05/09/2014       362.4         241.6  108.72  72.48      217.44        144.96
# 08/09/2014       398.4         265.6  119.52  79.68      239.04        159.36
# 12/09/2014       406.8         271.2  122.04  81.36      244.08        162.72
# 16/09/2014       445.8         297.2  133.74  89.16      267.48        178.32
#
#             Old Male  Old Female
# Date
# ...

# %%
Guinea.isnull().sum()
# Out:
# Country                    0
# No. of confirmed cases     0
# No. of confirmed deaths    0
# Male Cases                 0
# Female Cases               0
# Boys                       0
# Girls                      0
# Adult Male                 0
# Adult Female               0
# Old Male                   0
# Old Female                 0
# dtype: int64

# %%
Guinea.shape
# Out:
# (259, 11)

# %%
guinea_infectados=Guinea['No. of confirmed cases'][0:-1:10] #asignamos variable de infectados
guinea_muertos=Guinea['No. of confirmed deaths'][0:-1:10] #asignamos variable para las muertes
fechas=Guinea.index[0:-1:10]  #extraemos las fechas para el rango propuesto [0:-1:10]
plt.figure(figsize=(10,5)) #comenzamos a graficar
plt.plot(fechas,guinea_infectados, 'o:r', ms=3, label='Infectados')
plt.plot(fechas,guinea_muertos,'o-b', ms=3,label='Muertos')
plt.grid() #malla de la gráfica
plt.title('Comparación entre infectados y decesos')
plt.xlabel('Fechas')
plt.ylabel('Número de casos')
guinea_infectados=Guinea['No. of confirmed cases'][0:-1:10] #asignamos variable de infectados
guinea_muertos=Guinea['No. of confirmed deaths'][0:-1:10] #asignamos variable para las muertes
fechas=Guinea.index[0:-1:10]  #extraemos las fechas para el rango propuesto [0:-1:10]
plt.figure(figsize=(10,5)) #comenzamos a graficar
plt.plot(fechas,guinea_infectados, 'o:r', ms=3, label='Infectados')
plt.plot(fechas,guinea_muertos,'o-b', ms=3,label='Muertos')
plt.grid() #malla de la gráfica
plt.title('Comparación entre infectados y decesos')
plt.xlabel('Fechas')
plt.ylabel('Número de casos')
plt.legend()
plt.xticks(rotation=90,fontsize=8)
plt.savefig('Infectadosmuertos.png', dpi=300, format='png')
plt.show()

# %%
guinea_boys=Guinea['Boys'][0:-1:10]
guinea_girls=Guinea['Girls'][0:-1:10]
fechas=Guinea.index[0:-1:10]
plt.figure(figsize=(10,8))
plt.plot(fechas,guinea_boys,'o:r',ms=3, label='Niños')
plt.plot(fechas,guinea_girls,'o-b',ms=3,label='Niñas')
plt.grid
plt.title('Comparacion entre nños y niñas')
plt.xlabel('Fechas')
plt.ylabel('Numero de casos')
plt.legend()
plt.xticks(rotation=90, fontsize=8)
plt.savefig('NiñosNiñas.png', dpi=300, format='png')
plt.show()

# %%
FC=Guinea['Female Cases'][0:-1:10]
G=Guinea['Girls'][0:-1:10]
AF=Guinea ['Adult Female'][0:-1:10]
OF=Guinea ['Old Female'][0:-1:10]

fechas=Guinea.index[0:-1:10]

plt.figure(figsize=(10,8))
plt.bar(fechas,FC, color='red', label='Total',alpha=0.6)
plt.bar(fechas,G, color='blue', label='Niñas', alpha=0.6)
plt.bar(fechas,AF,color='green', label='Adultas', alpha=0.6)
plt.bar(fechas, OF, color='yellow', label='Adultas mayores', alpha=0.6)
plt.grid()
plt.title('Casos por edad')
plt.xlabel('Fechas')
plt.ylabel('Numero de casos')
plt.legend()
plt.xticks(rotation=90, fontsize=8)
plt.savefig('Casos por edad.png', dpi=300, format='png')
plt.show()
